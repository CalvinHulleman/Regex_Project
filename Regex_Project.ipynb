# %% [markdown]
# <a href="https://colab.research.google.com/github/CalvinHulleman/Regex_Project/blob/main/Regex_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Scraping Alan's Wikipedia page

# %%
import re
import urllib.request
hand = urllib.request.urlopen('https://en.wikipedia.org/wiki/Alan_Turing')
def ascii_histogram(seq) -> None: #create a histogram from a list of numbers
  counted = count_elements(seq) #generate frequency table (dictionary)
  for key in sorted(counted):
    plus_str = '+' * counted[key]
    print(f'{key} {plus_str}') #prints out asterisk
def count_elements(seq): #creates a dictionary
  hist = dict()
  for date in seq:
    hist[date] = hist.get(date,0)+ 1
  return hist

dates = []
for line in hand:
  line = line.decode().strip()
  dates.extend(re.findall('[\s-]((18|19|20)[0-9]{2})[^0-9]',line))

ascii_histogram(dates)
# Out:
# ('1845', '18') +
# ('1885', '18') ++++
# ('1907', '19') +
# ('1911', '19') +
# ('1912', '19') +++++
# ('1922', '19') ++
# ('1926', '19') ++
# ('1927', '19') ++
# ('1928', '19') ++
# ('1930', '19') +++++
# ('1931', '19') +++
# ('1933', '19') +
# ('1934', '19') +++
# ('1935', '19') +++
# ('1936', '19') ++++++
# ('1937', '19') +++
# ('1938', '19') ++++
# ('1939', '19') +++++++++++
# ('1940', '19') +++++
# ('1941', '19') ++++
# ('1942', '19') ++++
# ('1943', '19') ++
# ('1945', '19') +++++++
# ('1946', '19') ++++
# ('1947', '19') ++++
# ('1948', '19') ++++
# ('1950', '19') ++++++
# ('1951', '19') ++++++++++
# ('1952', '19') ++++++++++
# ('1954', '19') +++++++++++++++++
# ('1955', '19') +
# ('1959', '19') +++
# ('1960', '19') ++++
# ('1967', '19') +
# ('1971', '19') ++++
# ('1972', '19') +
# ('1978', '19') +
# ('1980', '19') +
# ('1983', '19') +++++++++++++++++++++++++
# ('1985', '19') +
# ('1986', '19') +
# ('1988', '19') +
# ('1989', '19') +
# ('1990', '19') +
# ('1992', '19') +
# ...
